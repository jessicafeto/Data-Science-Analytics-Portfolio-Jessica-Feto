# %% [markdown]
# ```
# By: Jessica Feto
#
# ```

# %% [markdown]
# # Model Representation![Screenshot 2024-02-18 at 00.41.42.png](data:image/png;base64,...)

# %% [markdown]
# The goal of this laboratory work is to implement the model for linear regression with one variable. For this, I will use NumPy for scientific computing and Matplotilb to plot the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem Statement
# In this example, I am going to use house price prediction. This lab will use a simple data set with only two data points:
#
# - A house with \( 1,000 \) square feet (sqft) sold for \( \$300,000 \).
# - A house with \( 2,000 \) square feet sold for \( \$500,000 \).
#
# These two points will constitute our data or training set. In this lab, the units of size are \( 1,000 \) sqft, and the units of price are \( 1,000s \) of dollars.

# %% [markdown]
# ![Screenshot 2024-02-18 at 00.52.52.png](data:image/png;base64,...)

# %% [markdown]
# In this case, I would like to fit a linear regression model ( shown abouve as the blue straight line) through these two points, so then I can predict the price for other houses.

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %% [markdown]
# ## Number of training examples `m`

# %% [markdown]
# `In this lab ` **`m`** `is going to be used to denote the number of training examples.  Numpy arrays have a .shape parameter. x_train.shape returns a python tuple with an entry for each dimension. x_train.shape[0] is the length of the array and number of examples as shown below.`

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2

# %% [markdown]
# ## Training example `x_i, y_i`

# %% [markdown]
# I am going to use ($x^{(i)}$ , $y^{(i)}$) to denote the $i^{(th)}$ training example. Since python is zero indexed, ($x^{(0)}$, $y^{(0)}$) is now (1.0, 300.0) and ($x^{(1)}$, $y^{(1)}$) is (2.0, 500.0).

# %%
i = 0
x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %% [markdown]
# ## Plotting the data

# %% [markdown]
# In order to plot these two points, i am going to use the `scatter()`  function in the `matplotlib` library.

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %% [markdown]
# ## Model Function
#
# The model function for linear regression is represented as $f_{w,b}(x^{(i)} = wx^{(i)} + b$ .

# %% [markdown]
# The formula above is how tou can represent straight lines - different values of $w$ and $b$ give you different straight lines on the plot.

# %% [markdown]
# ![Screenshot 2024-02-18 at 01.28.43.png](data:image/png;base64,...)

# %% [markdown]
# Try to get a better understanding for this by staring with $w$ = 100 and $b$ = 100 .

# %%
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %% [markdown]
# Now I am going to compute the value of $f_{w,b}(x^{(i)} for your two data points.
#
# The formula would be like this for each data point:
#
# for $x^{(0)}$ , `f_wb = w * x[0] + b
# for $x^{(1)}$ , `f_wb = w * x[1] + b
#
# For a large number of datapoints, this can get unwieldy and repetitive. Instead, the function is better to be calcualted inside a `for` loop as shown in the ` compute_model_output` function below.

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples
      w,b (scalar)    : model parameters
    Returns
      y (ndarray (m,)): target values
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b

    return f_wb

# %% [markdown]
# Now i am going to call the `compute_model_output` function and plot the output.

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %% [markdown]
# As it can be seen, setting $w$ = 100 and $b$ = 100 does not result in a line that fits the data.
#
#
# And now that we have a model, we can use it to make our original prediction. Let's predict the price of a house with 1200 sqft. Since the units of
# $x$ are in 1000's of sqft, $x$ is 1.2.

# %%
w = 200
b = 100
x_i = 1.2
cost_1200sqft = w * x_i + b

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Linear Regression builds a model which estabileshes a relationship between features and targets.
#
# In this example, the feature was house size and the target was the house price. For simple linear regression, the model has two paramters $w$ and $b$ whose values are 'fit' using the training data. Once a model's parameters have been determined, the model can be used to make predicions on novel data.
